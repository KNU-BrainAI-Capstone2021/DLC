# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
driver = webdriver.Chrome('chromedriver')

# %%
import time

#무신사 접속
driver.get('https://store.musinsa.com/app/')
#정보를 로딩하는 시간을 기다리기
time.sleep(2)

# %%
def cloth_searching(word):
    
    url = 'https://search.musinsa.com/search/musinsa/integration?type=&q=' + word
    return url

# %%
#검색결과 페이지 접속하기
word = "블랙 슬랙스"
url = cloth_searching(word)
driver.get(url)

# %%
#HTML에서 코디 찾아 클릭하기
def cody(driver):
    first = driver.find_element_by_xpath('/html/body/div[2]/div[3]/section/div[3]/div/section[2]/header/a/h2')
    first.click()
    time.sleep(3)
cody(driver)

# %%
def select_first(driver):
    first = driver.find_element_by_xpath('/html/body/div[2]/div[3]/section/div[4]/div/div[3]/ul/li[1]/div[2]/a/strong')
    first.click()
    time.sleep(3)
select_first(driver)

# %%
#style_info > div.styling_goods.codimap-goods > div > div > div > div.styling_list.swiper-wrapper > div.swiper-slide.style_contents_size.swiper-slide-active > a.brand_item
#style_info > div.styling_goods.codimap-goods > div > div > div > div.styling_list.swiper-wrapper > div.swiper-slide.style_contents_size.swiper-slide-next > a.brand_item
#style_info > div.styling_goods.codimap-goods > div > div > div > div.styling_list.swiper-wrapper > div:nth-child(3) > a.brand_item
#style_info > div.styling_goods.codimap-goods > div > div > div > div.styling_list.swiper-wrapper > div:nth-child(4) > a.brand_item
#style_info > div.styling_goods.codimap-goods > div > div > div > div.styling_list.swiper-wrapper > div:nth-child(5) > a.brand_item

#style_info > div.styling_goods.codimap-goods > div > div > div > div.styling_list.swiper-wrapper > div.swiper-slide.style_contents_size.swiper-slide-active > a.brand_item

# %%
#게시글 정보 가져오기
import re
from bs4 import BeautifulSoup
import unicodedata

def get_content_1(driver):
    # 1. 현재 페이지 html 정보 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')
    # 2. 본문내용 가져오기
    try:
        content = soup.select('#style_info > div.styling_goods.codimap-goods > div > div > div > div.styling_list.swiper-wrapper > div.swiper-slide.style_contents_size.swiper-slide-active > a.brand_item')[0].text
        content = unicodedata.normalize('NFC', content)
        content = content.replace('\n','')
        content = content.replace('\t','')
    except:
        content = ' '
    data.append(content)
    return data

# %%
def get_content_2(driver):
    # 1. 현재 페이지 html 정보 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')
    # 2. 본문내용 가져오기
    try:
        content = soup.select('#style_info > div.styling_goods.codimap-goods > div > div > div > div.styling_list.swiper-wrapper > div.swiper-slide.style_contents_size.swiper-slide-next > a.brand_item')[0].text
        content = unicodedata.normalize('NFC', content)
        content = content.replace('\n','')
        content = content.replace('\t','')
    except:
        content = ' '
    data.append(content)
    return data

# %%
def get_content_3(driver):
    # 1. 현재 페이지 html 정보 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')
    # 2. 본문내용 가져오기
    try:
        content = soup.select('#style_info > div.styling_goods.codimap-goods > div > div > div > div.styling_list.swiper-wrapper > div:nth-child(3) > a.brand_item')[0].text
        content = unicodedata.normalize('NFC', content)
        content = content.replace('\n','')
        content = content.replace('\t','')
    except:
        content = ' '
    data.append(content)
    return data

# %%
def get_content_4(driver):
    # 1. 현재 페이지 html 정보 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')
    # 2. 본문내용 가져오기
    try:
        content = soup.select('#style_info > div.styling_goods.codimap-goods > div > div > div > div.styling_list.swiper-wrapper > div:nth-child(4) > a.brand_item')[0].text
        content = unicodedata.normalize('NFC', content)
        content = content.replace('\n','')
        content = content.replace('\t','')
    except:
        content = ' '
    data.append(content)
    return data

# %%
def get_content_5(driver):
    # 1. 현재 페이지 html 정보 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')
    # 2. 본문내용 가져오기
    try:
        content = soup.select('#style_info > div.styling_goods.codimap-goods > div > div > div > div.styling_list.swiper-wrapper > div:nth-child(5) > a.brand_item')[0].text
        content = unicodedata.normalize('NFC', content)
        content = content.replace('\n','')
        content = content.replace('\t','')
    except:
        content = ' '
    data.append(content)
    return data

# %%
import re
from bs4 import BeautifulSoup
import unicodedata
#비어있는 변수 만들기
results = []
#여러 게시글 수집하기
for i in range(1,61):
    data=[]
    #게시글 수집에 오류 발생시 2초 대기 후, 다음 글로 넘어가기
    try:
        move = driver.find_element_by_xpath(f'/html/body/div[2]/div[3]/section/div[4]/div/div[3]/ul/li[{i}]/div[1]/a/div/img')
        move.click()
        time.sleep(3)
        data=get_content_1(driver)
        data=get_content_2(driver)
        data=get_content_3(driver)
        data=get_content_4(driver)
        data=get_content_5(driver)
        results.append(data)
        driver.back()
        time.sleep(3)
    except:
        time.sleep(3)
        move = driver.find_element_by_xpath(f'/html/body/div[2]/div[3]/section/div[4]/div/div[3]/ul/li[{i}]/div[1]/a/div/img')
        move.click()
        driver.back()
        time.sleep(3)
print(results)
# Out:
# [['3M 신슐레이트 바시티 자켓 네이비', '[벨리곰 콜라보] BELLY GOM FACE 남여공용 오버핏 맨투맨 BMM104 (BLACK)', '미니멀 스탠다드 세미 와이드 카고 조거 슬랙스 Black', '디에프엠 빅사이즈 라이트 다크 그레이-볼캡', '오버사이즈 로고 웨이스트백 블랙'], ['오버핏 비건레더 보머 자켓 (브라운)', '캐시미어 블렌드 라운드 니트 네이비', '프렌치 벨티드 와이드 슬랙스 블랙', '와이드 머플러 Black', 'Alecto 크로노그래프 메탈시계 SP3340M-GRG'], ['미니멀 울 블루종 (그레이 베이지)', 'STRIPE OVER FIT KNIT KA [BLACK]', '[섀도우 밴딩]롱 와이드 슬랙스 블랙_FW', '울 플리츠 머플러 라이트그레이', '[MARK-4] REGULAR MINI (BLACK)'], ['후드 데님 셔츠 자켓 -흑청', '[Mmlg] 1987 SWEAT (GREY)', '미니멀 스탠다드 세미 와이드 카고 조거 슬랙스 Black', '숏비니 인디고', 'JIMMY M LOGO AIRPOD CASE(MG2BFMAB96A)'], [' ', ' ', ' ', ' ', ' '], ['브라운 헤링본 그레타 백 스티치 울 자켓 / BROWN HERRINGBONE GRETA BACK STITCH WOOL JACKET', '로고 클래식 셔츠v2', '[4WAY STRETCH] 블랙 기모 스트레치 슬림핏 슬랙스 (320X21DY15)', 'SILVER 라린느 귀걸이_JAREXG021', '[D-LOCK] 블랙 D장식 가죽 토트백 DCBA1F967BK'], ['우먼즈 글렌 체크 오버사이즈 블레이저 [미디엄 그레이]', '우먼즈 미니멀 크루 넥 니트 [미디엄 그레이]', '우먼즈 베이식 블라우스 [화이트]', '우먼즈 웨이스트밴들리스 와이드 슬랙스 [블랙]', '미니엘 여성시계 컬렉션 S 화이트 - 블랙 PV603BK'], ['캐시미어 더블 롱 코트 BLACK', '아가일 체크 램스 울 니트 가디건 블랙 CO
# ...

# %%
#/html/body/div[2]/div[3]/section/div[4]/div/div[3]/ul/li[60]/div[1]/a/div/img

# %%
import pandas as pd
import numpy as np

# %%
af=np.array(results)

# %%
af
# Out:
# array([['3M 신슐레이트 바시티 자켓 네이비',
#         '[벨리곰 콜라보] BELLY GOM FACE 남여공용 오버핏 맨투맨 BMM104 (BLACK)',
#         '미니멀 스탠다드 세미 와이드 카고 조거 슬랙스 Black', '디에프엠 빅사이즈 라이트 다크 그레이-볼캡',
#         '오버사이즈 로고 웨이스트백 블랙'],
#        ['오버핏 비건레더 보머 자켓 (브라운)', '캐시미어 블렌드 라운드 니트 네이비',
#         '프렌치 벨티드 와이드 슬랙스 블랙', '와이드 머플러 Black',
#         'Alecto 크로노그래프 메탈시계 SP3340M-GRG'],
#        ['미니멀 울 블루종 (그레이 베이지)', 'STRIPE OVER FIT KNIT KA [BLACK]',
#         '[섀도우 밴딩]롱 와이드 슬랙스 블랙_FW', '울 플리츠 머플러 라이트그레이',
#         '[MARK-4] REGULAR MINI (BLACK)'],
#        ['후드 데님 셔츠 자켓 -흑청', '[Mmlg] 1987 SWEAT (GREY)',
#         '미니멀 스탠다드 세미 와이드 카고 조거 슬랙스 Black', '숏비니 인디고',
#         'JIMMY M LOGO AIRPOD CASE(MG2BFMAB96A)'],
#        [' ', ' ', ' ', ' ', ' '],
#        ['브라운 헤링본 그레타 백 스티치 울 자켓 / BROWN HERRINGBONE GRETA BACK STITCH WOOL JACKET',
#         '로고 클래식 셔츠v2', '[4WAY STRETCH] 블랙 기모 스트레치 슬림핏 슬랙스 (320X21DY15)',
#         'SILVER 라린느 귀걸이_JAREXG021', '[D-LOCK] 블랙 D장식 가죽 토트백 DCBA1F967BK'],
# ...

# %%
df=pd.DataFrame(af)

# %%
df
# Out:
#                                                     0  \
# 0                                 3M 신슐레이트 바시티 자켓 네이비
# 1                                오버핏 비건레더 보머 자켓 (브라운)
# 2                                 미니멀 울 블루종 (그레이 베이지)
# 3                                     후드 데님 셔츠 자켓 -흑청
# 4
# 5   브라운 헤링본 그레타 백 스티치 울 자켓 / BROWN HERRINGBONE GRE...
# 6                      우먼즈 글렌 체크 오버사이즈 블레이저 [미디엄 그레이]
# 7                                  캐시미어 더블 롱 코트 BLACK
# 8
# 9
# 10
# 11
# 12                    RECYCLED LEATHER JACKET - BLACK
# 13                              BOUCLE BLAZER - BLACK
# 14            RECYCLED NYLON SINGLE TRENCH - CHARCOAL
# 15                               프리미엄 울 오버핏 트렌치 코트 블랙
# 16
# 17                                        울 블루종 (그레이)
# 18
# 19
# 20                               라이트웨이트 베이식 블레이저 [블랙]
# 21                              오버사이즈 싱글 코트 [라이트 그레이]
# 22                                우먼즈 오버사이즈 블레이저 [블랙]
# 23  SHADE KHAKI OVER-FIT BLANC HALF DOUBLE TRENCH ...
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.columns=['outer', 'top', 'bottom', 'acc1', 'acc2']

# %%
df.to_csv('musinsa_test.csv', encoding='utf-8-sig')
